# %% [markdown]
# ### # módulos são arquivos que servem para organizar funções, classes e variáveis relacionadas, existem também os pacotes, que são pastas com função de agrupar módulos relacionados

# %%
#Este código no notebook realiza um comando de importação do módulo Pacotes.tel. 
# A parte à direita do ponto, tel, corresponde ao módulo em si e um arquivo tel.py dentro da pasta Pacotes
import Pacotes.tel
print(Pacotes.tel.ddi)

# %%
import Pacotes.tel as br_tel
import Pacotes.RJ.tel as rj_tel
import Pacotes.PE.tel as pe_tel
print(br_tel.ddi)
print('\n DDI do Brasil', br_tel.ddi, '\n DDD do Rio de Janeiro', rj_tel.ddds ,'\n DDD de Pernambuco', pe_tel.ddds)
